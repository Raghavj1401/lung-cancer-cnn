# %%
import tensorflow as tf

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/Lung Cancer Detection Dataset/train",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

valid_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/Lung Cancer Detection Dataset/valid",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    "../data/Lung Cancer Detection Dataset/test",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 613 files belonging to 4 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772390397.807991   16210 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1763 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 72 files belonging to 4 classes.
# Found 315 files belonging to 4 classes.

# %%
import os
print(os.getcwd())
# Out:
# /home/raghav/Documents/Projects/lung-cancer-cnn/notebooks
